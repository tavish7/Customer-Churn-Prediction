# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Display Settings to display all columns
pd.set_option('display.max_columns', None)

# %%
# Load the dataset
df = pd.read_excel("Telco_customer_churn.xlsx")
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
# Check the number of rows and columns and meta data information
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.info()
# Out:
# Rows: 7043
# Columns: 33
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
# ...

# %% [markdown]
# We have 7043 rows and 33 columns in the dataset. There are few columns that are not required for the analysis. We will inspect the data types of the columns to understand the data better and further inspect the data for any missing values, outliers and inconsistencies and will handle them accordingly.

# %%
# Trim spaces, lowercase, and replace internal spaces with underscores
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# Check for the data types
data_types = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.values
})
data_types
# Out:
#                Column Data Type
# 0          customerid       str
# 1               count     int64
# 2             country       str
# 3               state       str
# 4                city       str
# 5            zip_code     int64
# 6            lat_long       str
# 7            latitude   float64
# 8           longitude   float64
# 9              gender       str
# 10     senior_citizen       str
# 11            partner       str
# 12         dependents       str
# 13      tenure_months     int64
# 14      phone_service       str
# 15     multiple_lines       str
# 16   internet_service       str
# 17    online_security       str
# 18      online_backup       str
# 19  device_protection       str
# 20       tech_support       str
# 21       streaming_tv       str
# 22   streaming_movies       str
# 23           contract       str
# 24  paperless_billing       str
# 25     payment_method       str
# 26    monthly_charges   float64
# 27      total_charges    object
# ...

# %%
# Almost all the columns have correct data types. The only issue is that the TotalCharges column is an object type. We will convert it to a float.
# Rest of the columns we can keep as is for now for understanding the data better and will handle them later during the data cleaning process.

df['total_charges'] = pd.to_numeric(df['total_charges'], errors='coerce')

# %%
# Check for duplicates and remove them
duplicates = df.duplicated().sum()
print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %%
# Check for statistics of the dataset
df.describe().T
# Out:
#                   count          mean          std           min  \
# count            7043.0      1.000000     0.000000      1.000000
# zip_code         7043.0  93521.964646  1865.794555  90001.000000
# latitude         7043.0     36.282441     2.455723     32.555828
# longitude        7043.0   -119.798880     2.157889   -124.301372
# tenure_months    7043.0     32.371149    24.559481      0.000000
# monthly_charges  7043.0     64.761692    30.090047     18.250000
# total_charges    7032.0   2283.300441  2266.771362     18.800000
# churn_value      7043.0      0.265370     0.441561      0.000000
# churn_score      7043.0     58.699418    21.525131      5.000000
# cltv             7043.0   4400.295755  1183.057152   2003.000000
#
#                           25%           50%           75%           max
# count                1.000000      1.000000      1.000000      1.000000
# zip_code         92102.000000  93552.000000  95351.000000  96161.000000
# ...

# %% [markdown]
# - In total there are **7043** *rows* and **33** *columns* in the dataset.
# - There are **11** *missing values* in the *TotalCharges* column and we need to handle them.
# - There is a massive *positive skewness* in the *TotalCharges* column i.e. a long tail on the right side of the distribution having small groups of customers with high charges.
# - There is an **imbalance** in the dataset as the mean of churn_value is 0.265370 which is *26.5% of the customers churned*.
# - Customer *tenure ranges* from *0 to 72 months* i.e. from a brand new customer to a customer who has been with the company for 6 years.
# - There is a slight *negative skewness* in the *monthly_charges* column, which depicts that there are few customers with very high monthly charges and large chunk of customers have low monthly charges.

# %%
# Remove the columns that are not required for the analysis
remove_columns = [
    'count', # It is always 1
    'country', # We have only one country
    'state', # We have only one state
    'churn_reason', # It is not required for the analysis
    'lat_long' # Redundant column
]

df.drop(columns=remove_columns, inplace=True)

print(df.shape)
# Out:
# (7043, 28)

# %%
df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %%
df.shape
# Out:
# (7043, 28)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# customerid            0
# city                  0
# zip_code              0
# latitude              0
# longitude             0
# gender                0
# senior_citizen        0
# partner               0
# dependents            0
# tenure_months         0
# phone_service         0
# multiple_lines        0
# internet_service      0
# online_security       0
# online_backup         0
# device_protection     0
# tech_support          0
# streaming_tv          0
# streaming_movies      0
# contract              0
# paperless_billing     0
# payment_method        0
# monthly_charges       0
# total_charges        11
# churn_label           0
# churn_value           0
# churn_score           0
# cltv                  0
# dtype: int64

# %% [markdown]
# For **total_charges** column, we have **11 missing values**. Most of the customers have current tenure as 0 months i.e. they are *brand new customers* and have a valid tenure. So, we can *impute* the missing values *with the current monthly charges*.

# %%
# Impute the missing values with the current monthly charges
df['total_charges'] = df['total_charges'].fillna(df['monthly_charges'])
print(df.isnull().sum())
# Out:
# customerid           0
# city                 0
# zip_code             0
# latitude             0
# longitude            0
# gender               0
# senior_citizen       0
# partner              0
# dependents           0
# tenure_months        0
# phone_service        0
# multiple_lines       0
# internet_service     0
# online_security      0
# online_backup        0
# device_protection    0
# tech_support         0
# streaming_tv         0
# streaming_movies     0
# contract             0
# paperless_billing    0
# payment_method       0
# monthly_charges      0
# total_charges        0
# churn_label          0
# churn_value          0
# churn_score          0
# cltv                 0
# dtype: int64

# %%
# Check for outliers
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
outlier_summary = []

for col in num_cols:
    Q1 = df[col].quantile(.25)
    Q3 = df[col].quantile(.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR

    count = ((df[col] < lower) | (df[col] > upper)).sum()

    outlier_summary.append([col,count])

outliers = pd.DataFrame(outlier_summary, columns=['Feature','Outliers'])

outliers.sort_values(by='Outliers', ascending=False)
# Out:
#            Feature  Outliers
# 0         zip_code         0
# 1         latitude         0
# 2        longitude         0
# 3    tenure_months         0
# 4  monthly_charges         0
# 5    total_charges         0
# 6      churn_value         0
# 7      churn_score         0
# 8             cltv         0

# %% [markdown]
# There are no outliers in the data set

# %% [markdown]
# ### Feature Engineering

# %%
# Tenure Groups
def categorize_tenure(months):
    if months <= 12:
        return '0-1 Year'
    elif months <= 24:
        return '1-2 Years'
    elif months <= 48:
        return '2-4 Years'
    else:
        return '4+ Years'

df['tenure_group'] = df['tenure_months'].apply(categorize_tenure)
df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %%
# Average monthly usage
'''
df['avg_monthly_usage'] = np.where(
    df['monthly_charges'] > 0,
    df['total_charges'] / df['tenure_months'],
    df['monthly_charges']
)


df['avg_monthly_usage'] = np.where(
    df['tenure_months'] == 0,
    0,  
    df['total_charges'] / df['tenure_months'] 
)
'''

df['avg_monthly_usage'] = (df['total_charges'] / df['tenure_months']).replace([np.inf, -np.inf], 0).fillna(0)

df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %%
# Payment risk category
risk_map = {
    'Electronic check' : 'High Risk',
    'Mailed check' : 'Medium Risk',
    'Bank transfer (automatic)' : 'Low Risk',
    'Credit card (automatic)' : 'Low Risk'
}
df['payment_risk'] = df['payment_method'].map(risk_map)

# %%
# Customer Value Segment (Customer Life Time Value)
df['customer_value_segment'] = pd.qcut(
    df['cltv'],
    q=4,
    labels=[
        'Bronze',
        'Silver',
        'Gold',
        'Platinum'
    ]
)

# %%
# number of services used
service_columns = [
    'phone_service', 'multiple_lines', 'internet_service', 
    'online_security', 'online_backup', 'device_protection', 
    'tech_support', 'streaming_tv', 'streaming_movies'
]

df['total_services'] = 0

for col in service_columns:
    if col == 'internet_service':

        df['total_services'] += df[col].isin(['DSL', 'Fiber optic']).astype(int)
    else:
        df['total_services'] += (df[col] == 'Yes').astype(int)

# %%
df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %% [markdown]
# ### Exploratory Analysis

# %%
# Customer churn distribution
plt.figure(figsize=(10, 7))
ax = sns.countplot(data=df, x='churn_label', palette='viridis')
plt.title('Customer Churn Distribution', fontsize=14, fontweight='bold')
plt.ylabel('Customer Count')
for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=3, fontsize=12)

plt.show()

# %% [markdown]
# This depicts that there are a total of **1869 customers** who have been **churned** and **5174** are **continuing their contract**. There is a significant *imbalance* in the data that we have to fix it to ensure there is no bias in the prediction model. To do this we can use *SMOTE (Synthetic Minority Over-sampling Technique)*, that generates a new synthetic minority data points by interpolating between existing minority samples rather than simply duplicating them.

# %%
categorical_cols = ['tenure_group', 'payment_risk', 'customer_value_segment', 
                    'contract', 'internet_service', 'total_services', 
                    'gender', 'senior_citizen', 'dependents']

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 18))
axes = axes.flatten()

for i, col in enumerate(categorical_cols):
    ax = axes[i]
    
    sns.countplot(data=df, x=col, hue='churn_label', ax=ax, palette='viridis')
    ax.set_title(f'Churn by {col}')
    ax.tick_params(axis='x', rotation=45)

    for container in ax.containers:
        ax.bar_label(container, fmt='%d', padding=3)


plt.tight_layout()
plt.show()

# %%
if 'churn_numeric' not in df.columns:
    df['churn_numeric'] = df['churn_label'].map({'Yes': 1, 'No': 0})

categorical_cols = ['tenure_group', 'payment_risk', 'customer_value_segment', 
                    'contract', 'internet_service', 'total_services', 
                    'gender', 'senior_citizen', 'dependents']

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 18))
axes = axes.flatten()

for i, col in enumerate(categorical_cols):
    ax = axes[i]
    
   
    sns.barplot(data=df, x=col, y='churn_numeric', ax=ax, palette='viridis', errorbar=None)
    
    ax.set_title(f'Churn Ratio by {col}', fontsize=14, fontweight='bold')
    ax.tick_params(axis='x', rotation=45)
    ax.set_ylabel('Churn Risk')
    ax.set_xlabel('')
    
    ax.set_ylim(0, 1)

   
    for container in ax.containers:

        labels = [f"{(bar.get_height() * 100):.1f}%" for bar in container]
        ax.bar_label(container, labels=labels, padding=3, fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **Churn Ratio by Tenure Group**
#    Churn ratio is about 47.4% for the customers where tenure is for 1-2 years. This can be due to the reason that most of the customers got new or better offers from compitiors in the market.
#
# 2. **Churn Ratio by Payment Risk**

# %%
# Monthly Charge vs churn
plt.figure(figsize=(12, 6))

sns.kdeplot(
    data=df, 
    x='monthly_charges', 
    hue='churn_label', 
    fill=True, 
    palette='Set1', 
    alpha=0.5
)

plt.title('Monthly Charges vs. Churn', fontsize=14, fontweight='bold')
plt.xlabel('Monthly Charges ($)')
plt.ylabel('Density of Customers')

plt.show()

# %%
df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %%
df.drop(columns = 'churn_numeric', inplace=True)

# %%
df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %%
# Convert to csv file to further inspect in sql
df.drop(columns='churn_value')
df.to_csv("customer_churn_clean.csv", index=False) # By default, Pandas saves the row index as an unnamed first column, so we use index=False to drop it.

# %%
df.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %% [markdown]
# ### Preprocessing

# %%
# Create a copy of data
df_clean = df.copy()
df_clean.head()
# Out:
#    customerid         city  zip_code   latitude   longitude  gender  \
# 0  3668-QPYBK  Los Angeles     90003  33.964131 -118.272783    Male
# 1  9237-HQITU  Los Angeles     90005  34.059281 -118.307420  Female
# 2  9305-CDSKC  Los Angeles     90006  34.048013 -118.293953  Female
# 3  7892-POOKP  Los Angeles     90010  34.062125 -118.315709  Female
# 4  0280-XJGEX  Los Angeles     90015  34.039224 -118.266293    Male
#
#   senior_citizen partner dependents  tenure_months phone_service  \
# 0             No      No         No              2           Yes
# 1             No      No        Yes              2           Yes
# 2             No      No        Yes              8           Yes
# 3             No     Yes        Yes             28           Yes
# 4             No      No        Yes             49           Yes
#
#   multiple_lines internet_service online_security online_backup  \
# 0             No              DSL             Yes           Yes
# ...

# %%
# Remove unwanted column
df_clean.drop(columns = 'churn_label', inplace=True)

# %%
# Convert categorical features to numerical features for training purposes as ML models will understand numerical data much better


# Binary (Yes=1, No=0 | Male=1, Female=0)
if 'gender' in df_clean.columns:
    df_clean['gender'] = df_clean['gender'].map({'Male': 1, 'Female': 0})

yes_no_cols = ['senior_citizen', 'partner', 'dependents', 'phone_service', 'paperless_billing']
for col in yes_no_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].map({'Yes': 1, 'No': 0})

# Ordinal Encoding for ranked features
ordinal_mappings = {
    'tenure_group': {'0-1 Year': 0, '1-2 Years': 1, '2-4 Years': 2, '4+ Years': 3},
    'payment_risk': {'Low Risk': 0, 'Medium Risk': 1, 'High Risk': 2},
    'customer_value_segment': {'Bronze': 0, 'Silver': 1, 'Gold': 2, 'Platinum': 3}
}

for col, mapping in ordinal_mappings.items():
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].map(mapping)

# One-Hot Encoding for remaining Nominal categories
nominal_cols = ['multiple_lines', 'internet_service', 'online_security', 
                'online_backup', 'device_protection', 'tech_support', 
                'streaming_tv', 'streaming_movies', 'contract', 'payment_method']


df_encoded = pd.get_dummies(df_clean, columns=nominal_cols, drop_first=True, dtype=int)

print(f"Data shape after encoding: {df_encoded.shape}")

# Save the ML-ready dataset
df_encoded.to_csv('customer_churn_encoded.csv', index=False)
# Out:
# Data shape after encoding: (7043, 43)

# %%
# Correlation matrix

plt.figure(figsize=(10, 12))

numeric_df = df_encoded.select_dtypes(include=['number'])

# Calculate correlations and isolate just the relationship with 'churn_value'
correlations = numeric_df.corr()['churn_value'].sort_values(ascending=False)

# Drop 'churn_value' itself so it doesn't just show a 100% match with itself
if 'churn_value' in correlations:
    correlations = correlations.drop('churn_value')
    
# Also drop 'churn_score' and 'cltv' if they are in there to prevent data leakage!
cols_to_drop = ['churn_score', 'cltv']
correlations = correlations.drop(labels=[col for col in cols_to_drop if col in correlations.index], errors='ignore')

# Plot as a horizontal bar chart
sns.barplot(x=correlations.values, y=correlations.index, palette='coolwarm')
plt.title('Feature Correlation with Churn (Positive vs. Negative Drivers)', fontsize=14, fontweight='bold')
plt.xlabel('Correlation Coefficient (Pearson)')
plt.ylabel('Features')
plt.axvline(x=0, color='black', linestyle='-', linewidth=1)
plt.show()

# %%
# Create a heatmap
numeric_df = df_encoded.select_dtypes(include=['number'])

# Drop features that cause leakage
cols_to_drop = ['churn_score', 'cltv']
df_filtered = numeric_df.drop(columns=[col for col in cols_to_drop if col in numeric_df.columns])

full_corr_matrix = df_filtered.corr()

plt.figure(figsize=(24, 20))

# Create a custom diverging colormap (Blue for negative, Red for positive)
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(full_corr_matrix, annot=False, cmap=cmap, vmin=-1, vmax=1,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})

plt.title('Full Correlation Heatmap Matrix', fontsize=24, fontweight='bold')
plt.xticks(rotation=90, fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# %%
numeric_df = df_encoded.select_dtypes(include=['number'])

# Drop features that cause leakage
cols_to_drop = ['churn_score', 'cltv']
df_filtered = numeric_df.drop(columns=[col for col in cols_to_drop if col in numeric_df.columns])

# Find the Top 20 features most strongly correlated with churn_value
corr_with_churn = df_filtered.corr()['churn_value'].abs().sort_values(ascending=False)
top_20_features = corr_with_churn.head(20).index

top_20_corr_matrix = df_filtered[top_20_features].corr()

plt.figure(figsize=(16, 14))

# Create a custom diverging colormap (Blue for negative, Red for positive)
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(top_20_corr_matrix, annot=True, fmt=".2f", cmap=cmap, vmin=-1, vmax=1,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})

plt.title('Correlation Heatmap Matrix (Top 20 Features)', fontsize=18, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# %%
# Feature Importance
from sklearn.ensemble import RandomForestClassifier

numeric_df = df_encoded.select_dtypes(include=['number'])

cols_to_drop = ['churn_value', 'churn_score', 'cltv']
X = numeric_df.drop(columns=[col for col in cols_to_drop if col in numeric_df.columns])
y = numeric_df['churn_value']

rf_baseline = RandomForestClassifier(n_estimators=100, random_state=42)
rf_baseline.fit(X, y)

importances = pd.Series(rf_baseline.feature_importances_, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(x=importances.head(20).values, y=importances.head(20).index, palette='viridis')

plt.title('Top 20 Feature Importances', fontsize=14, fontweight='bold')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.show()
